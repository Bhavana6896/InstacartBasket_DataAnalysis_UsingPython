# %% [markdown]
# # Imporing Libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Python data types

# %% [markdown]
# ## Three ways to reach 100 using variables

# %%
#Addition

a = 40
b = 60

# %%
print(a + b)
# Out:
# 100

# %%
#Subtraction

x = 150
y = 50

# %%
print(x - y)
# Out:
# 100

# %%
#Addition using more than 2 variables

m = 70
n = 20
o = 10

# %%
print(m + n + o)
# Out:
# 100

# %%
type(m + n + o)
# Out:
# int

# %% [markdown]
# ##  Two floating-point variables, divided  by each other

# %%
number1 = 10.5
number2 = 2.5

# %%
print(number1/number2)
# Out:
# 4.2

# %%
type(number1/number2)
# Out:
# float

# %% [markdown]
# ## Short word from seperate strings

# %%
stringS = 'Data'
stringT = 'base'

# %%
print(stringS + stringT)
# Out:
# Database

# %%
type(stringS + stringT)
# Out:
# str

# %% [markdown]
# ## Long words and sentence concatenation

# %%
string1 = 'Data '
string2 = 'Analytics '
string3 = 'Is Fun!'

# %%
sentenceA = string1 + string2 + string3

# %%
print(sentenceA)
# Out:
# Data Analytics Is Fun!

# %%
type(sentenceA)
# Out:
# str

# %% [markdown]
# ## Long words and sentence concatenation

# %%
stringP = 'Hi! My '
stringQ = 'name is '
stringR = 'Bhavana Sawant.'

# %%
sentenceB = stringP + stringQ + stringR

# %%
print(sentenceB)
# Out:
# Hi! My name is Bhavana Sawant.

# %% [markdown]
# Boolean

# %%
sentenceA == sentenceB
# Out:
# False

# %%
type(sentenceA == sentenceB)
# Out:
# bool
