# %% [markdown]
# # 01. Importing libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02. Data types.

# %%
# Integers

# %%
x = 2

# %%
x
# Out:
# 2

# %%
print(x)
# Out:
# 2

# %%
type(x)
# Out:
# int

# %%
# Floating Point Numbers

# %%
y = 5.678

# %%
y
# Out:
# 5.678

# %%
type(y)
# Out:
# float

# %%
# String - has to be in quotation marks

# %%
z = 'Brazil'

# %%
z
# Out:
# 'Brazil'

# %%
type(z)
# Out:
# str

# %%
# Boolean - True and False

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %%
x + 4
# Out:
# 6

# %%
x * y
# Out:
# 11.356

# %%
x + y
# Out:
# 7.678

# %%
x = x + 4

# %%
print(x)
# Out:
# 6

# %%
a = 'Hello, '

# %%
b =  'Bhavana'

# %%
print(a + b)
# Out:
# Hello, Bhavana

# %%
n = 'youcandothis!'

# %%
n * 23
# Out:
# 'youcandothis!youcandothis!youcandothis!youcandothis!youcandothis!youcandothis!youcandothis!youcandothis!youcandothis!youcandothis!youcandothis!youcandothis!youcandothis!youcandothis!youcandothis!youcandothis!youcandothis!youcandothis!youcandothis!youcandothis!youcandothis!youcandothis!youcandothis!'

# %%
print(n)
# Out:
# youcandothis!

# %%
x == y
# Out:
# False

# %%
type(x==y)
# Out:
# bool
