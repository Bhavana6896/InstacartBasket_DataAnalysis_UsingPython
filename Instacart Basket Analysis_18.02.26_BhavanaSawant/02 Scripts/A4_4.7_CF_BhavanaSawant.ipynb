# %% [markdown]
# # Importing Libraries and Dataset

# %%
import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\bhava\Documents\18.02.26_Instacart Basket Analysis'

# %%
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_merge.pkl'))

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2539329        1             1                  2                  8
# 2   2539329        1             1                  2                  8
# 3   2539329        1             1                  2                  8
# 4   2539329        1             1                  2                  8
#
#    days_since_last_order  product_id  add_to_cart_order  reordered  \
# 0                    NaN         196                  1          0
# 1                    NaN       14084                  2          0
# 2                    NaN       12427                  3          0
# 3                    NaN       26088                  4          0
# 4                    NaN       26405                  5          0
#
#    Unnamed: 0                             product_name  aisle_id  \
# ...

# %%
ords_prods_merge.shape
# Out:
# (32404859, 15)

# %% [markdown]
# # Removing unnessecary column Unnamed: 0 and rewriting the name

# %%
ords_prods_merge = ords_prods_merge.drop(columns = ['Unnamed: 0'])

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2539329        1             1                  2                  8
# 2   2539329        1             1                  2                  8
# 3   2539329        1             1                  2                  8
# 4   2539329        1             1                  2                  8
#
#    days_since_last_order  product_id  add_to_cart_order  reordered  \
# 0                    NaN         196                  1          0
# 1                    NaN       14084                  2          0
# 2                    NaN       12427                  3          0
# 3                    NaN       26088                  4          0
# 4                    NaN       26405                  5          0
#
#                               product_name  aisle_id  department_id  prices  \
# ...

# %%
# number after the colon: this indicates that the subset should include everything from the beginning of the dataframe up to that number

df = ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 14)

# %%
df
# Out:
#         order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0        2539329        1             1                  2                  8
# 1        2539329        1             1                  2                  8
# 2        2539329        1             1                  2                  8
# 3        2539329        1             1                  2                  8
# 4        2539329        1             1                  2                  8
# ...          ...      ...           ...                ...                ...
# 999995   2789027     6474             2                  3                  8
# 999996   2789027     6474             2                  3                  8
# 999997   2789027     6474             2                  3                  8
# 999998   2789027     6474             2                  3                  8
# 999999   2789027     6474             2                  3                  8
#
# ...

# %%
def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return np.nan

# %%
df['price_range'] = df.apply(price_label, axis=1)

# This axis = 1 stands for “rows,” so this code essentially tells Python to apply the function to all rows within the dataframe. Conversely, axis = 0 would refer to all columns within the dataframe.
# Out:
# C:\Users\bhava\AppData\Local\Temp\ipykernel_22608\808061328.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
df.head(10)
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2539329        1             1                  2                  8
# 2   2539329        1             1                  2                  8
# 3   2539329        1             1                  2                  8
# 4   2539329        1             1                  2                  8
# 5   2398795        1             2                  3                  7
# 6   2398795        1             2                  3                  7
# 7   2398795        1             2                  3                  7
# 8   2398795        1             2                  3                  7
# 9   2398795        1             2                  3                  7
#
#    days_since_last_order  product_id  add_to_cart_order  reordered  \
# 0                    NaN         196                  1          0
# ...

# %%
df.shape
# Out:
# (1000000, 15)

# %%
df['price_range'].value_counts(dropna = False)
# Out:
# price_range
# Mid-range product    673183
# Low-range product    314392
# High range            12425
# Name: count, dtype: int64

# %%
df['prices'].max()
# Out:
# 99999.0

# %% [markdown]
# # Using loc(), you can apply the conditional logic of an if-statement to a function without explicitly creating an if-else construct
# ##  The difference here is that there’s no explicit if in your if-statement. Instead, it’s all been implied.

# %%
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'

ords_prods_merge.loc[ords_prods_merge['prices'] > 15, 'price_range_loc'] = 'High-range product'
# Out:
# C:\Users\bhava\AppData\Local\Temp\ipykernel_22608\2108514796.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
ords_prods_merge.loc[ (ords_prods_merge['prices'] <= 15) & (ords_prods_merge['prices'] > 5), 'price_range_loc' ] = 'Mid-range product'

# %%
ords_prods_merge.loc[ords_prods_merge['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
ords_prods_merge['price_range_loc'].value_counts(dropna = False)
# Out:
# price_range_loc
# Mid-range product     21860860
# Low-range product     10126321
# High-range product      417678
# Name: count, dtype: int64

# %%
ords_prods_merge['price_range_loc']
# Out:
# 0           Mid-range product
# 1           Mid-range product
# 2           Low-range product
# 3           Low-range product
# 4           Low-range product
#                   ...
# 32404854    Mid-range product
# 32404855    Mid-range product
# 32404856    Low-range product
# 32404857    Low-range product
# 32404858    Low-range product
# Name: price_range_loc, Length: 32404859, dtype: object

# %% [markdown]
# # For loops

# %%
ords_prods_merge['order_day_of_week'].value_counts(dropna = False)
# Out:
# order_day_of_week
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: count, dtype: int64

# %%
result = []

for value in ords_prods_merge["order_day_of_week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %% [markdown]
# # Busiest Day

# %%
ords_prods_merge['busiest_day'] = result

# %%
ords_prods_merge['busiest_day'].value_counts(dropna = False)
# Out:
# busiest_day
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: count, dtype: int64

# %%
ords_prods_merge.head(10)
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2539329        1             1                  2                  8
# 2   2539329        1             1                  2                  8
# 3   2539329        1             1                  2                  8
# 4   2539329        1             1                  2                  8
# 5   2398795        1             2                  3                  7
# 6   2398795        1             2                  3                  7
# 7   2398795        1             2                  3                  7
# 8   2398795        1             2                  3                  7
# 9   2398795        1             2                  3                  7
#
#    days_since_last_order  product_id  add_to_cart_order  reordered  \
# 0                    NaN         196                  1          0
# ...

# %% [markdown]
# # Busiest Days of the Week

# %%
result_2 = []

for value in ords_prods_merge["order_day_of_week"]:
    if value == 0 or value == 1:  
        result_2.append("Busiest days")
    elif value == 4 or value == 3: 
        result_2.append("Slowest days")
    else: 
        result_2.append("Regularly busy")

# %%
ords_prods_merge['busiest_days'] = result_2

# %%
ords_prods_merge['busiest_days'].value_counts(dropna = False)
# Out:
# busiest_days
# Regularly busy    12916111
# Busiest days      11864412
# Slowest days       7624336
# Name: count, dtype: int64

# %%
ords_prods_merge.head(10)
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2539329        1             1                  2                  8
# 2   2539329        1             1                  2                  8
# 3   2539329        1             1                  2                  8
# 4   2539329        1             1                  2                  8
# 5   2398795        1             2                  3                  7
# 6   2398795        1             2                  3                  7
# 7   2398795        1             2                  3                  7
# 8   2398795        1             2                  3                  7
# 9   2398795        1             2                  3                  7
#
#    days_since_last_order  product_id  add_to_cart_order  reordered  \
# 0                    NaN         196                  1          0
# ...

# %% [markdown]
# # Busiest period of the day

# %%
result_3 = []

for value in ords_prods_merge["order_hour_of_day"]:
    if value in [10, 11, 14, 15, 13, 12, 16, 9]: 
        result_3.append("Most orders")
    elif value in [23, 6, 0, 1, 5, 2, 4, 3]: 
        result_3.append("Fewest orders")
    else: 
        result_3.append("Average orders")

# %%
ords_prods_merge["busiest_period_of_day"] = result_3

# %%
ords_prods_merge["busiest_period_of_day"].value_counts(dropna = False)
# Out:
# busiest_period_of_day
# Most orders       21118071
# Average orders     9997651
# Fewest orders      1289137
# Name: count, dtype: int64

# %%
ords_prods_merge.head(10)
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2539329        1             1                  2                  8
# 2   2539329        1             1                  2                  8
# 3   2539329        1             1                  2                  8
# 4   2539329        1             1                  2                  8
# 5   2398795        1             2                  3                  7
# 6   2398795        1             2                  3                  7
# 7   2398795        1             2                  3                  7
# 8   2398795        1             2                  3                  7
# 9   2398795        1             2                  3                  7
#
#    days_since_last_order  product_id  add_to_cart_order  reordered  \
# 0                    NaN         196                  1          0
# ...

# %%
ords_prods_merge.tail(10)
# Out:
#           order_id  user_id  order_number  order_day_of_week  \
# 32404849    626363   206209            12                  1
# 32404850   2977660   206209            13                  1
# 32404851   2977660   206209            13                  1
# 32404852   2977660   206209            13                  1
# 32404853   2977660   206209            13                  1
# 32404854   2977660   206209            13                  1
# 32404855   2977660   206209            13                  1
# 32404856   2977660   206209            13                  1
# 32404857   2977660   206209            13                  1
# 32404858   2977660   206209            13                  1
#
#           order_hour_of_day  days_since_last_order  product_id  \
# 32404849                 12                   18.0       14727
# 32404850                 12                    7.0       24852
# 32404851                 12                    7.0        9405
# ...

# %%
ords_prods_merge.shape
# Out:
# (32404859, 18)

# %%
ords_prods_merge["busiest_period_of_day"].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0           Average orders
# 1           Average orders
# 2           Average orders
# 3           Average orders
# 4           Average orders
#                  ...
# 32404854       Most orders
# 32404855       Most orders
# 32404856       Most orders
# 32404857       Most orders
# 32404858       Most orders
# Name: busiest_period_of_day, Length: 32404859, dtype: object>

# %%
ords_prods_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32404859 entries, 0 to 32404858
# Data columns (total 18 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   order_id               int64
#  1   user_id                int64
#  2   order_number           int64
#  3   order_day_of_week      int64
#  4   order_hour_of_day      int64
#  5   days_since_last_order  float64
#  6   product_id             int64
#  7   add_to_cart_order      int64
#  8   reordered              int64
#  9   product_name           object
#  10  aisle_id               int64
#  11  department_id          int64
#  12  prices                 float64
#  13  _merge                 category
#  14  price_range_loc        object
#  15  busiest_day            object
#  16  busiest_days           object
#  17  busiest_period_of_day  object
# dtypes: category(1), float64(2), int64(10), object(5)
# memory usage: 4.1+ GB

# %% [markdown]
# # Export

# %%
ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'ords_prods_merge_clean.pkl'))
