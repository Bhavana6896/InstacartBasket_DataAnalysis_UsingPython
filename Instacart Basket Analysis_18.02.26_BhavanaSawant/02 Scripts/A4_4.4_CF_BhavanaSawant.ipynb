# %% [markdown]
# # Importing

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\bhava\Documents\18.02.26_Instacart Basket Analysis'

# %%
path
# Out:
# 'C:\\Users\\bhava\\Documents\\18.02.26_Instacart Basket Analysis'

# %% [markdown]
# # Importing dataset folders

# %%
df_ords = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'orders.csv'), index_col = False)

# %%
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'products.csv'), index_col = False)

# %% [markdown]
# # Dropping Columns
#
# df.drop(columns = ['variable'])

# %%
df_ords.drop(columns = ['eval_set'])
# Out:
#          order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0         2539329        1             1          2                  8
# 1         2398795        1             2          3                  7
# 2          473747        1             3          3                 12
# 3         2254736        1             4          4                  7
# 4          431534        1             5          4                 15
# ...           ...      ...           ...        ...                ...
# 3421078   2266710   206209            10          5                 18
# 3421079   1854736   206209            11          4                 10
# 3421080    626363   206209            12          1                 12
# 3421081   2977660   206209            13          1                 12
# 3421082    272231   206209            14          6                 14
#
#          days_since_prior_order
# 0                           NaN
# 1                          15.0
# ...

# %% [markdown]
# #  If you wanted to remove the "eval_set" column from df_ords and have the result of that removal be the new df_ords
#
# If you had a variable, x, and you wanted to add a value of “2” to that variable, you could write x + 2. However, this only acted like a calculator. It printed the result of the equation, but the value of x stayed the same. If you wanted to actually add “2” to x and have the result of that equation be the new x, you’d need to write x = x + 2.

# %%
df_ords = df_ords.drop(columns = ['eval_set'])

# %% [markdown]
# #  alternative to overwriting a dataframe is to create a new version with a different name
#
# df_ords_2 = df_ords.drop(columns = ['eval_set'])

# %%
df_ords.value_counts()
# Out:
# order_id  user_id  order_number  order_dow  order_hour_of_day  days_since_prior_order
# 1         112108   4             4          10                 9.0                       1
# 2280953   767      13            1          18                 23.0                      1
# 2280955   119072   10            5          13                 29.0                      1
# 2280956   135372   72            5          18                 3.0                       1
# 2280957   73662    6             1          13                 8.0                       1
#                                                                                         ..
# 1140724   131093   21            1          16                 6.0                       1
# 1140725   85700    21            2          11                 6.0                       1
# 1140726   201418   25            6          10                 3.0                       1
# ...

# %%
df_ords.head(10)
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2398795        1             2          3                  7
# 2    473747        1             3          3                 12
# 3   2254736        1             4          4                  7
# 4    431534        1             5          4                 15
# 5   3367565        1             6          2                  7
# 6    550135        1             7          1                  9
# 7   3108588        1             8          1                 14
# 8   2295261        1             9          1                 16
# 9   2550362        1            10          4                  8
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0
# 5                    19.0
# 6                    20.0
# 7                    14.0
# ...

# %% [markdown]
# # to find missing variables  and thier count
#
# df['variable'].value_counts(dropna = False)

# %%
df_ords['days_since_prior_order'].value_counts(dropna = False)
# Out:
# days_since_prior_order
# 30.0    369323
# 7.0     320608
# 6.0     240013
# 4.0     221696
# 3.0     217005
# 5.0     214503
# NaN     206209
# 2.0     193206
# 8.0     181717
# 1.0     145247
# 9.0     118188
# 14.0    100230
# 10.0     95186
# 13.0     83214
# 11.0     80970
# 12.0     76146
# 0.0      67755
# 15.0     66579
# 16.0     46941
# 21.0     45470
# 17.0     39245
# 20.0     38527
# 18.0     35881
# 19.0     34384
# 22.0     32012
# 28.0     26777
# 23.0     23885
# 27.0     22013
# 24.0     20712
# 25.0     19234
# 29.0     19191
# 26.0     19016
# Name: count, dtype: int64

# %% [markdown]
# # to find variables existing value that are NOT missing and thier count/frenquecy - remove the dropna funtion
# This syntax—df['variable']—is the standard way of accessing a column within a dataframe using pandas.
#
# df['variable'].value_counts

# %%
df_ords['days_since_prior_order'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0           NaN
# 1          15.0
# 2          21.0
# 3          29.0
# 4          28.0
#            ...
# 3421078    29.0
# 3421079    30.0
# 3421080    18.0
# 3421081     7.0
# 3421082    30.0
# Name: days_since_prior_order, Length: 3421083, dtype: float64>

# %% [markdown]
# # df.rename() function, The final argument, inplace = true, means that you want to overwrite the original column name with this new column name rather than creating a new copy.
#
# df.rename(columns = {'old_name' : 'new_name'}, inplace = True)

# %%
df_ords.rename(columns = {'order_dow' : 'order_day_of_week'}, inplace = True)

# %%
df_ords.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2398795        1             2                  3                  7
# 2    473747        1             3                  3                 12
# 3   2254736        1             4                  4                  7
# 4    431534        1             5                  4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
df_ords.rename(columns = {'order_dow' : 'order_day_of_week'}, inplace = True)

# %%
df_ords.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2398795        1             2                  3                  7
# 2    473747        1             3                  3                 12
# 3   2254736        1             4                  4                  7
# 4    431534        1             5                  4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
df_ords.describe()
# Out:
#            order_id       user_id  order_number  order_day_of_week  \
# count  3.421083e+06  3.421083e+06  3.421083e+06       3.421083e+06
# mean   1.710542e+06  1.029782e+05  1.715486e+01       2.776219e+00
# std    9.875817e+05  5.953372e+04  1.773316e+01       2.046829e+00
# min    1.000000e+00  1.000000e+00  1.000000e+00       0.000000e+00
# 25%    8.552715e+05  5.139400e+04  5.000000e+00       1.000000e+00
# 50%    1.710542e+06  1.026890e+05  1.100000e+01       3.000000e+00
# 75%    2.565812e+06  1.543850e+05  2.300000e+01       5.000000e+00
# max    3.421083e+06  2.062090e+05  1.000000e+02       6.000000e+00
#
#        order_hour_of_day  days_since_prior_order
# count       3.421083e+06            3.214874e+06
# mean        1.345202e+01            1.111484e+01
# std         4.226088e+00            9.206737e+00
# min         0.000000e+00            0.000000e+00
# 25%         1.000000e+01            4.000000e+00
# 50%         1.300000e+01            7.000000e+00
# ...

# %% [markdown]
# # changing data type to string

# %%
df_ords['order_id'] = df_ords['order_id'].astype('str')

# %%
df_ords.describe()
# Out:
#             user_id  order_number  order_day_of_week  order_hour_of_day  \
# count  3.421083e+06  3.421083e+06       3.421083e+06       3.421083e+06
# mean   1.029782e+05  1.715486e+01       2.776219e+00       1.345202e+01
# std    5.953372e+04  1.773316e+01       2.046829e+00       4.226088e+00
# min    1.000000e+00  1.000000e+00       0.000000e+00       0.000000e+00
# 25%    5.139400e+04  5.000000e+00       1.000000e+00       1.000000e+01
# 50%    1.026890e+05  1.100000e+01       3.000000e+00       1.300000e+01
# 75%    1.543850e+05  2.300000e+01       5.000000e+00       1.600000e+01
# max    2.062090e+05  1.000000e+02       6.000000e+00       2.300000e+01
#
#        days_since_prior_order
# count            3.214874e+06
# mean             1.111484e+01
# std              9.206737e+00
# min              0.000000e+00
# 25%              4.000000e+00
# 50%              7.000000e+00
# 75%              1.500000e+01
# max              3.000000e+01

# %%
df_ords['order_id'].dtype
# Out:
# dtype('O')

# %% [markdown]
# # Importing department dataset

# %%
df_dep = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'departments.csv'), index_col = False)

# %%
df_dep.head()
# Out:
#   department_id       1      2       3        4        5              6  \
# 0    department  frozen  other  bakery  produce  alcohol  international
#
#            7     8                9  ...            12      13         14  \
# 0  beverages  pets  dry goods pasta  ...  meat seafood  pantry  breakfast
#
#              15          16         17      18      19    20       21
# 0  canned goods  dairy eggs  household  babies  snacks  deli  missing
#
# [1 rows x 22 columns]

# %% [markdown]
# # Transpose

# %%
df_dep.T
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
df_dep_t = df_dep.T

# %%
df_dep_t
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %% [markdown]
# # Adding an index

# %%
df_dep_t.reset_index()
# Out:
#             index                0
# 0   department_id       department
# 1               1           frozen
# 2               2            other
# 3               3           bakery
# 4               4          produce
# 5               5          alcohol
# 6               6    international
# 7               7        beverages
# 8               8             pets
# 9               9  dry goods pasta
# 10             10             bulk
# 11             11    personal care
# 12             12     meat seafood
# 13             13           pantry
# 14             14        breakfast
# 15             15     canned goods
# 16             16       dairy eggs
# 17             17        household
# 18             18           babies
# 19             19           snacks
# 20             20             deli
# 21             21          missing

# %% [markdown]
# ##  1) Create a new header; 2) Remove the first row in the dataframe; and 3) Add the new header

# %% [markdown]
# # take the row under the current header (the first row in the dataframe), use that data to create a new header

# %%
new_header = df_dep_t.iloc[0]

# %% [markdown]
# # “locate an integer” = iloc.

# %%
new_header
# Out:
# 0    department
# Name: department_id, dtype: object

# %%
df_dep_t_new = df_dep_t[1:]

# %%
df_dep_t_new
# Out:
#                   0
# 1            frozen
# 2             other
# 3            bakery
# 4           produce
# 5           alcohol
# 6     international
# 7         beverages
# 8              pets
# 9   dry goods pasta
# 10             bulk
# 11    personal care
# 12     meat seafood
# 13           pantry
# 14        breakfast
# 15     canned goods
# 16       dairy eggs
# 17        household
# 18           babies
# 19           snacks
# 20             deli
# 21          missing

# %% [markdown]
# # add the new header to the new df

# %%
df_dep_t_new.columns = new_header

# %%
new_header
# Out:
# 0    department
# Name: department_id, dtype: object

# %%
df_dep_t_new
# Out:
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %% [markdown]
# # Data Dictionary

# %%
# Data Dictionary using prods and dep - department_id

# %%
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
data_dict = df_dep_t_new.to_dict('index')

# %%
data_dict
# Out:
# {'1': {'department': 'frozen'},
#  '2': {'department': 'other'},
#  '3': {'department': 'bakery'},
#  '4': {'department': 'produce'},
#  '5': {'department': 'alcohol'},
#  '6': {'department': 'international'},
#  '7': {'department': 'beverages'},
#  '8': {'department': 'pets'},
#  '9': {'department': 'dry goods pasta'},
#  '10': {'department': 'bulk'},
#  '11': {'department': 'personal care'},
#  '12': {'department': 'meat seafood'},
#  '13': {'department': 'pantry'},
#  '14': {'department': 'breakfast'},
#  '15': {'department': 'canned goods'},
#  '16': {'department': 'dairy eggs'},
#  '17': {'department': 'household'},
#  '18': {'department': 'babies'},
#  '19': {'department': 'snacks'},
#  '20': {'department': 'deli'},
#  '21': {'department': 'missing'}}

# %%
print(data_dict.get('19'))
# Out:
# {'department': 'snacks'}

# %% [markdown]
# # Subsetting

# %% [markdown]
# # object['element'] syntax is called indexing
#
# Indexing refers to retrieving some element from an object, be it a dataframe, list, or otherwise. By using the index operator,[], you’re telling Python to look for the element in the brackets within the object to the left of the brackets (so, in this case, looking for a "department_id" value of 19 within the df_prods dataframe).

# %%
df_snacks =  df_prods[df_prods['department_id']==19]

# %%
df_prods['department_id']==19
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 49688    False
# 49689    False
# 49690    False
# 49691    False
# 49692    False
# Name: department_id, Length: 49693, dtype: bool

# %%
df_prods[df_prods['department_id']==19]
# Out:
#        product_id                                   product_name  aisle_id  \
# 0               1                     Chocolate Sandwich Cookies        61
# 15             16                  Mint Chocolate Flavored Syrup       103
# 24             25        Salted Caramel Lean Protein & Fiber Bar         3
# 31             32                  Nacho Cheese White Bean Chips       107
# 40             41    Organic Sourdough Einkorn Crackers Rosemary        78
# ...           ...                                            ...       ...
# 49666       49662                   Bacon Cheddar Pretzel Pieces       107
# 49669       49665  Super Dark Coconut Ash & Banana Chocolate Bar        45
# 49670       49666                  Ginger Snaps Snacking Cookies        61
# 49675       49671                           Milk Chocolate Drops        45
# 49683       49679                        Famous Chocolate Wafers        61
#
#        department_id  prices
# 0                 19     5.8
# ...

# %%
df_snacks =  df_prods[df_prods['department_id']==19]

# %%
df_snacks.head()
# Out:
#     product_id                                 product_name  aisle_id  \
# 0            1                   Chocolate Sandwich Cookies        61
# 15          16                Mint Chocolate Flavored Syrup       103
# 24          25      Salted Caramel Lean Protein & Fiber Bar         3
# 31          32                Nacho Cheese White Bean Chips       107
# 40          41  Organic Sourdough Einkorn Crackers Rosemary        78
#
#     department_id  prices
# 0              19     5.8
# 15             19     5.2
# 24             19     1.9
# 31             19     4.9
# 40             19     6.5

# %% [markdown]
# # another method to achieve same results - loc looks for a column name

# %%
df_snacks_2 = df_prods.loc[df_prods['department_id'] == 19]

# %%
df_snacks_2.head()
# Out:
#     product_id                                 product_name  aisle_id  \
# 0            1                   Chocolate Sandwich Cookies        61
# 15          16                Mint Chocolate Flavored Syrup       103
# 24          25      Salted Caramel Lean Protein & Fiber Bar         3
# 31          32                Nacho Cheese White Bean Chips       107
# 40          41  Organic Sourdough Einkorn Crackers Rosemary        78
#
#     department_id  prices
# 0              19     5.8
# 15             19     5.2
# 24             19     1.9
# 31             19     4.9
# 40             19     6.5

# %%
df_snacks_3 = df_prods.loc[df_prods['department_id'].isin([19])]

# %%
df_snacks_3.head()
# Out:
#     product_id                                 product_name  aisle_id  \
# 0            1                   Chocolate Sandwich Cookies        61
# 15          16                Mint Chocolate Flavored Syrup       103
# 24          25      Salted Caramel Lean Protein & Fiber Bar         3
# 31          32                Nacho Cheese White Bean Chips       107
# 40          41  Organic Sourdough Einkorn Crackers Rosemary        78
#
#     department_id  prices
# 0              19     5.8
# 15             19     5.2
# 24             19     1.9
# 31             19     4.9
# 40             19     6.5

# %% [markdown]
# # Exporting Data

# %% [markdown]
# df_ords.to_csv(os.path.join(path, '02 Data','Prepared Data', 'orders_wrangled.csv'))
#
# df_dep.to_csv(os.path.join(path, '02 Data','Prepared Data', 'departments_wrangled.csv'))

# %% [markdown]
# # Assignment 4.4

# %% [markdown]
# # 3. Another identifier variable in the df_ords dataframe that doesn’t need to be included in your analysis is 'user_id' - and changinig it to a string

# %%
df_ords['user_id'] = df_ords['user_id'].astype('str')

# %%
df_ords['user_id'].dtype
# Out:
# dtype('O')

# %%
df_ords.describe()
# Out:
#        order_number  order_day_of_week  order_hour_of_day  \
# count  3.421083e+06       3.421083e+06       3.421083e+06
# mean   1.715486e+01       2.776219e+00       1.345202e+01
# std    1.773316e+01       2.046829e+00       4.226088e+00
# min    1.000000e+00       0.000000e+00       0.000000e+00
# 25%    5.000000e+00       1.000000e+00       1.000000e+01
# 50%    1.100000e+01       3.000000e+00       1.300000e+01
# 75%    2.300000e+01       5.000000e+00       1.600000e+01
# max    1.000000e+02       6.000000e+00       2.300000e+01
#
#        days_since_prior_order
# count            3.214874e+06
# mean             1.111484e+01
# std              9.206737e+00
# min              0.000000e+00
# 25%              4.000000e+00
# 50%              7.000000e+00
# 75%              1.500000e+01
# max              3.000000e+01

# %% [markdown]
# ## Renaming days_since_prior_order

# %%
df_ords.rename(columns = {'days_since_prior_order' : 'days_since_last_order'}, inplace = True)

# %%
df_ords.head()
# Out:
#   order_id user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0  2539329       1             1                  2                  8
# 1  2398795       1             2                  3                  7
# 2   473747       1             3                  3                 12
# 3  2254736       1             4                  4                  7
# 4   431534       1             5                  4                 15
#
#    days_since_last_order
# 0                    NaN
# 1                   15.0
# 2                   21.0
# 3                   29.0
# 4                   28.0

# %% [markdown]
# ## Finding frequency

# %%
df_ords['order_hour_of_day'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0           8
# 1           7
# 2          12
# 3           7
# 4          15
#            ..
# 3421078    18
# 3421079    10
# 3421080    12
# 3421081    12
# 3421082    14
# Name: order_hour_of_day, Length: 3421083, dtype: int64>

# %%
df_ords["order_hour_of_day"].value_counts()
# Out:
# order_hour_of_day
# 10    288418
# 11    284728
# 15    283639
# 14    283042
# 13    277999
# 12    272841
# 16    272553
# 9     257812
# 17    228795
# 18    182912
# 8     178201
# 19    140569
# 20    104292
# 7      91868
# 21     78109
# 22     61468
# 23     40043
# 6      30529
# 0      22758
# 1      12398
# 5       9569
# 2       7539
# 4       5527
# 3       5474
# Name: count, dtype: int64

# %% [markdown]
# # Answer 4: The busiest hour is:
#
# 10:00 (10 AM) with 288,418 orders
#
# The frequency analysis of the order_hour_of_day variable shows that the busiest hour for placing orders is 10:00, with 288,418 orders. This is the highest count among all hours, closely followed by 11:00 and mid-afternoon hours. The results indicate that customer ordering activity peaks during late morning, suggesting that users are most active around this time of day.
#
# General Insights:
#
# • Ordering activity is heavily concentrated between 9 AM and 4 PM
# • Very low activity during late night / early morning (0–6)
# • Suggests daytime consumer behavior, not nighttime usage

# %% [markdown]
# ## Data Dictionary value of 4

# %%
print(data_dict.get('4'))
# Out:
# {'department': 'produce'}

# %% [markdown]
# # Answer 5: The value 4 represents Produce

# %% [markdown]
# ## 6. Subset of breakfast items in products

# %%
df_breakfast_1 =  df_prods[df_prods['department_id']==14]

# %%
df_breakfast_1.head()
# Out:
#      product_id                                      product_name  aisle_id  \
# 27           28                                 Wheat Chex Cereal       121
# 33           34                                               NaN       121
# 67           68                           Pancake Mix, Buttermilk       130
# 89           90                                      Smorz Cereal       121
# 210         211  Gluten Free Organic Cereal Coconut Maple Vanilla       130
#
#      department_id  prices
# 27              14    10.1
# 33              14    12.2
# 67              14    13.7
# 89              14     3.9
# 210             14     3.6

# %%
df_breakfast_1.tail()
# Out:
#        product_id                                       product_name  \
# 49330       49326                            Cereal Variety Fun Pack
# 49395       49391            Light and Fluffy Buttermilk Pancake Mix
# 49547       49543                          Chocolate Cheerios Cereal
# 49637       49633               Shake 'N Pour Buttermilk Pancake Mix
# 49667       49663  Ultra Protein Power Crunch Peanut Butter N' Ho...
#
#        aisle_id  department_id  prices
# 49330       121             14     9.1
# 49395       130             14     2.0
# 49547       121             14    10.8
# 49637       130             14    14.2
# 49667        57             14    10.2

# %%
df_breakfast_1["department_id"].value_counts()
# Out:
# department_id
# 14    1116
# Name: count, dtype: int64

# %% [markdown]
# ## 7. Subset for dinner parties: Alcohol, Deli, Beverages and Meat/Seafood which are 5, 20, 7 and 12 respectively

# %%
df_breakfast_2 = df_prods.loc[df_prods['department_id'].isin([5, 20, 7, 12])]

# %%
df_breakfast_2.head(10)
# Out:
#     product_id                                       product_name  aisle_id  \
# 2            3               Robust Golden Unsweetened Oolong Tea        94
# 6            7                     Pure Coconut Water With Orange        98
# 9           10     Sparkling Orange Juice & Prickly Pear Beverage       115
# 10          11                                  Peach Mango Juice        31
# 16          17                                  Rendered Duck Fat        35
# 19          20     Pomegranate Cranberry & Aloe Vera Enrich Drink        98
# 22          23                             Organic Turkey Burgers        49
# 34          35     Italian Herb Porcini Mushrooms Chicken Sausage       106
# 38          39           Daily Tangerine Citrus Flavored Beverage        64
# 39          40  Beef Hot Links Beef Smoked Sausage With Chile ...       106
#
#     department_id  prices
# 2               7     4.5
# 6               7     4.4
# 9               7     8.4
# ...

# %%
df_breakfast_2.tail(10)
# Out:
#        product_id                               product_name  aisle_id  \
# 49642       49638       Organic Superfirm Vacuum Packed Tofu        14
# 49655       49651                               Beef Brisket       122
# 49659       49655                                Apple Cider        98
# 49665       49661                                      Porto       134
# 49674       49670                        Beef Summer Sausage       106
# 49676       49672                     Cafe Mocha K-Cup Packs        26
# 49679       49675        Cinnamon Dolce Keurig Brewed K Cups        26
# 49680       49676                     Ultra Red Energy Drink        64
# 49686       49682                         California Limeade        98
# 49688       49684  Vodka, Triple Distilled, Twist of Vanilla       124
#
#        department_id  prices
# 49642             20     9.0
# 49655             12    20.7
# 49659              7    10.7
# 49665              5     8.2
# 49674             12    19.2
# ...

# %%
df_breakfast_2["department_id"].value_counts()
# Out:
# department_id
# 7     4365
# 20    1322
# 5     1056
# 12     907
# Name: count, dtype: int64

# %% [markdown]
# # Answer 8: Count of total items
#
# Breakfast items have a count of 1116 in the department dataset
# Alcohol items have a count of 4365 in the department dataset
# Deli items have a count of 1322 in the department dataset
# Beverage items have a count of 1056 in the department dataset
# Meat/Seafood items have a count of 907 in the department dataset

# %% [markdown]
# ## User ID 1 info

# %%
df_ords.head(10)
# Out:
#   order_id user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0  2539329       1             1                  2                  8
# 1  2398795       1             2                  3                  7
# 2   473747       1             3                  3                 12
# 3  2254736       1             4                  4                  7
# 4   431534       1             5                  4                 15
# 5  3367565       1             6                  2                  7
# 6   550135       1             7                  1                  9
# 7  3108588       1             8                  1                 14
# 8  2295261       1             9                  1                 16
# 9  2550362       1            10                  4                  8
#
#    days_since_last_order
# 0                    NaN
# 1                   15.0
# 2                   21.0
# 3                   29.0
# 4                   28.0
# 5                   19.0
# ...

# %%
df_ords[df_ords["user_id"] == 1]
# Out:
# Empty DataFrame
# Columns: [order_id, user_id, order_number, order_day_of_week, order_hour_of_day, days_since_last_order]
# Index: []

# %%
df_ords[df_ords["user_id"] == 1].shape
# Out:
# (0, 6)

# %% [markdown]
# ## Since we changed this earlier to a 'str', we can now change it back to an 'int' to evaluate it

# %%
df_ords['user_id'] = df_ords['user_id'].astype('int')

# %%
df_ords[df_ords["user_id"] == 1]
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2398795        1             2                  3                  7
# 2    473747        1             3                  3                 12
# 3   2254736        1             4                  4                  7
# 4    431534        1             5                  4                 15
# 5   3367565        1             6                  2                  7
# 6    550135        1             7                  1                  9
# 7   3108588        1             8                  1                 14
# 8   2295261        1             9                  1                 16
# 9   2550362        1            10                  4                  8
# 10  1187899        1            11                  4                  8
#
#     days_since_last_order
# 0                     NaN
# 1                    15.0
# ...

# %%
df_ords[df_ords["user_id"] == 1].shape
# Out:
# (11, 6)

# %%
df_ords[df_ords["user_id"] == 1].describe()
# Out:
#        user_id  order_number  order_day_of_week  order_hour_of_day  \
# count     11.0     11.000000          11.000000          11.000000
# mean       1.0      6.000000           2.636364          10.090909
# std        0.0      3.316625           1.286291           3.477198
# min        1.0      1.000000           1.000000           7.000000
# 25%        1.0      3.500000           1.500000           7.500000
# 50%        1.0      6.000000           3.000000           8.000000
# 75%        1.0      8.500000           4.000000          13.000000
# max        1.0     11.000000           4.000000          16.000000
#
#        days_since_last_order
# count              10.000000
# mean               19.000000
# std                 9.030811
# min                 0.000000
# 25%                14.250000
# 50%                19.500000
# 75%                26.250000
# max                30.000000

# %%
df_ords[df_ords["user_id"] == 1]["order_hour_of_day"].value_counts()
# Out:
# order_hour_of_day
# 8     3
# 7     3
# 12    1
# 15    1
# 9     1
# 14    1
# 16    1
# Name: count, dtype: int64

# %% [markdown]
# # df_ords[df_ords["user_id"] == 1]["orders_day_of_week"].value_counts()

# %%
df_ords[df_ords["user_id"] == 1]["days_since_last_order"].value_counts()
# Out:
# days_since_last_order
# 14.0    2
# 15.0    1
# 21.0    1
# 29.0    1
# 28.0    1
# 19.0    1
# 20.0    1
# 0.0     1
# 30.0    1
# Name: count, dtype: int64

# %%
df_ords[df_ords["user_id"] == 1]
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2398795        1             2                  3                  7
# 2    473747        1             3                  3                 12
# 3   2254736        1             4                  4                  7
# 4    431534        1             5                  4                 15
# 5   3367565        1             6                  2                  7
# 6    550135        1             7                  1                  9
# 7   3108588        1             8                  1                 14
# 8   2295261        1             9                  1                 16
# 9   2550362        1            10                  4                  8
# 10  1187899        1            11                  4                  8
#
#     days_since_last_order
# 0                     NaN
# 1                    15.0
# ...

# %% [markdown]
# ## Answer 8 and 9:
#
# # Basic Profile of user_id 1
#
# Filtering the dataset shows:
#
# Total orders: 11
#
# Variables observed: order timing, day of week, and days between orders
#
# This already tells us the user is not highly active compared to typical Instacart customers.
#
# # Ordering Time Behavior
#
# Most common hours: 7 AM and 8 AM (3 orders each)
#
# Remaining orders spread across daytime hours (9, 12, 14, 15, 16)
#
# This user strongly prefers early morning ordering, suggesting routine based purchasing, likely for daily or household needs rather than impulse buying.
#
# # Day of Week Behavior
#
# Orders by weekday:
#
# Day 4: 4 orders (most frequent)
#
# Day 1: 3 orders
#
# Days 2 and 3: 2 orders each
#
# Purchasing is not random. The user shows clustering on specific weekdays, implying habitual shopping patterns.
#
# # Days Between Orders
#
# Most common gap: 14 days
#
# Other gaps vary widely (15 to 30 days)
#
# One instance of 0 days
#
# This user appears to shop roughly every two weeks, but with some irregularity.
#
#
# The 0 day interval is the most interesting data point and could indicate: Same day repeat order, Order modification or correction
#
# # Data anomaly or duplicate transaction
#
# This is likely what the data engineers considered “strange.”
#
#
# ## Overview:
#
# User places infrequent orders (11 total)
#
# Strong preference for morning hours
#
# Orders cluster on specific weekdays
#
# Typical reorder cycle around two weeks
#
# Presence of an unusual 0 day reorder gap
#
# User 1 displays consistent behavioral patterns in both time of day and shopping frequency, with one potentially anomalous immediate reorder. This could warrant further investigation to determine whether it reflects genuine customer behavior or a data quality issue.

# %% [markdown]
# ## Exporting data

# %% [markdown]
# df_ords.to_csv(os.path.join(path, '02 Data','Prepared Data', 'orders_wrangled.csv'))

# %%
df_dep_t_new.to_csv(os.path.join(path, '02 Data','Prepared Data', 'departments_wrangled.csv'))

# %% [markdown]
# ## How to avoid the additional index column you get this with your export (by default) in the future:
# To prevent this, you should drop the index during the export phase, not the import phase. Whenever you save a wrangled dataset, always add index=False to your code:
# df.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'orders_wrangled.csv'), index=False)

# %%
df_ords.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'orders_wrangled.csv'), index=False)
